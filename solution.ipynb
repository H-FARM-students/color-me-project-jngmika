# %%
from PIL import Image
import sys
import math
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.colors import LogNorm

# %% [markdown]
# ### Mystery 1

# %%
df1 = np.loadtxt('MysteryData/Mystery1.data', delimiter=',')

# %%
plt.imshow(df1, cmap='viridis', norm=LogNorm())
plt.colorbar(label='My Numbers')
plt.savefig('colored_data/colored1.png')

plt.show()
plt.close()

# %% [markdown]
# ### Mystery 2

# %%
df2 = np.loadtxt('MysteryData/Mystery2.data', delimiter=',')

# %%
plt.imshow(df2, cmap='viridis', norm=LogNorm())
plt.colorbar(label='My Numbers')
plt.savefig('colored_data/colored2.png')

plt.show()
plt.close()

# %% [markdown]
# ## Mystery 3

# %%
df3 = np.loadtxt('MysteryData/Mystery3.data', delimiter=',')

plt.imshow(df3, cmap='Greys_r')
plt.colorbar(label='My Numbers')
plt.savefig('colored_data/colored3.png')

plt.show()
plt.close()

# %% [markdown]
# ## Mystery 4

# %%
df4 = np.loadtxt('MysteryData/Mystery4.data', delimiter=',')

plt.imshow(df4, cmap='viridis')
plt.colorbar(label='My Numbers')
plt.savefig('colored_data/colored4.png')

plt.show()
plt.close()

# %% [markdown]
# ## Mystery 5

# %%
df5 = np.loadtxt('MysteryData/Mystery5.data', delimiter=',')
plt.imshow(df5, cmap='viridis')
plt.colorbar(label='My Numbers')
plt.savefig('colored_data/colored5.png')

plt.show()
plt.close()
